# %%
import pandas as pd
import os

# dpath = os.path.join('preprocessed', '2022_season2_processed.csv')
# df = pd.read_csv(dpath,
#                  index_col=0,
#                  parse_dates=['대여일시', '반납일시'],
#                  infer_datetime_format=True)
dpath = os.path.join('postprocessed', 'data_around_cnu.csv')
df = pd.read_csv(dpath,
                 index_col=0,
                 parse_dates=['대여일시', '반납일시'],
                 infer_datetime_format=True)
rental = os.path.join('postprocessed', 'rental_around_cnu.csv')
df_rental = pd.read_csv(rental)
df.head()
# Out:
#      대여스테이션                대여일시  반납스테이션                반납일시  이동거리  rental_time
# 119     191 2022-07-25 16:33:58     413 2022-07-25 16:58:04  4000         1446
# 120     191 2022-07-25 16:34:40     413 2022-07-25 16:58:19  4000         1419
# 121     191 2022-07-25 16:34:48     413 2022-07-25 16:58:22  4000         1414
# 127     770 2022-07-25 17:18:12     202 2022-07-25 21:40:12  1000        15720
# 141     191 2022-07-25 18:00:37     444 2022-07-25 19:10:39  5500         4202

# %%
df_rental.head()
# Out:
#    번호   구분              대여소명    구    동         위도          경도
# 0  18  타슈2      다모아아파트 뒤 육교밑   서구  월평동  36.363085  127.366753
# 1  19  타슈2    은평공원 내 테니스장 입구   서구  월평동  36.358670  127.363647
# 2  22  타슈2    유성한가족 요양병원 소공원  유성구  봉명동  36.355079  127.350214
# 3  85  타슈2  충대정문오거리2(정문)(56)  유성구   궁동  36.361611  127.345168
# 4  96  타슈2          월평역 1번출구   서구  월평동  36.357998  127.364775

# %%
from matplotlib import pyplot as plt
import folium

pos_cnu = [36.3687979, 127.3468559]
map = folium.Map(location=pos_cnu, tiles='OpenStreetMap', zoom_start=13)
for _, data in df_rental.iterrows():
    folium.Marker(location=[data['위도'], data['경도']],
                  popup=folium.Popup(html=folium.IFrame(data['대여소명'], height=60), 
                                     min_width=200, max_width=200),
                  icon=folium.Icon()
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9eafe0479ff416b3199097dd20e67557 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9eafe0479ff416b3199097dd20e67557&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9eafe0479ff416b3199097dd20e67557 = L.map(
#                 &quot;map_9eafe0479ff416b3199097dd20e67557&quot;,
#                 {
#                     center: [36.3687979, 127.3468559],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d8aaceec7e940a237207ce21b6e974b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9eafe0479ff416b3199097dd20e67557);
#
#
#             var marker_ba074a73c66905a03a9943a5bf637626 = L.marker(
#                 [36.363085, 127.366753],
#                 {}
#             ).addTo(map_9eafe0479ff416b3199097dd20e67557);
#
#
#             var icon_47630138aef6f836e099989e6e93199a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ba074a73c66905a03a9943a5bf637626.setIcon(icon_47630138aef6f836e099989e6e93199a);
#
#
#         var popup_b23c91dd9f4507ec1af20e540af91bbd = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#
#                 var i_frame_1336e6f5744a263516a9301ee6f48c42 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICDri6TrqqjslYTslYTtjIztirgg65KkIOycoeq1kOuwkQ==&quot; width=&quot;100%&quot; style=&quot;border:none !important;&quot; height=&quot;60&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_b23c91dd9f4507ec1af20e540af91bbd.setContent(i_frame_1336e6f5744a263516a9301ee6f48c42);
#
#
#
#         marker_ba074a73c66905a03a9943a5bf637626.bindPopup(popup_b23c91dd9f4507ec1af20e540af91bbd)
#         ;
#
#
#
#
#             var marker_df7092b98b9bd2607040a80ac626a4d1 = L.marker(
#                 [36.35867, 127.363647],
#                 {}
#             ).addTo(map_9eafe0479ff416b3199097dd20e67557);
#
#
#             var icon_bdabbff76a31b6fd8d58d00f541cca12 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_df7092b98b9bd2607040a80ac626a4d1.setIcon(icon_bdabbff76a31b6fd8d58d00f541cca12);
#
#
#         var popup_8ece55f1f5c6367e2de817ad2653ae04 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#
#                 var i_frame_48b7bfe0dad40313ff8048119c6e6dc0 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICDsnYDtj4nqs7Xsm5Ag64K0IO2FjOuLiOyKpOyepSDsnoXqtaw=&quot; width=&quot;100%&quot; style=&quot;border:none !important;&quot; height=&quot;60&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_8ece55f1f5c6367e2de817ad2653ae04.setContent(i_frame_48b7bfe0dad40313ff8048119c6e6dc0);
#
#
#
#         marker_df7092b98b9bd2607040a80ac626a4d1.bindPopup(popup_8ece55f1f5c6367e2de817ad2653ae04)
#         ;
#
#
#
#
#             var marker_31d1bff098a7eab72f8682b72521c468 = L.marker(
#                 [36.355079, 127.350214],
#                 {}
#             ).addTo(map_9eafe0479ff416b3199097dd20e67557);
#
#
#             var icon_61b5c9140578bd1403a36c8ae89ff82b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_31d1bff098a7eab72f8682b72521c468.setIcon(icon_61b5c9140578bd1403a36c8ae89ff82b);
#
#
#         var popup_399c869dacff0a2fe3ba838c5bd43dbe = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#
#                 var i_frame_972250adb6322a1ece56990bf9d8fbcc = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICDsnKDshLHtlZzqsIDsobEg7JqU7JaR67OR7JuQIOyGjOqzteybkA==&quot; width=&quot;100%&quot; style=&quot;border:none !important;&quot; height=&quot;60&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_399c869dacff0a2fe3ba838c5bd43dbe.setContent(i_frame_972250adb6322a1ece56990bf9d8fbcc);
#
#
#
#         marker_31d1bff098a7eab72f8682b72521c468.bindPopup(popup_399c869dacff0a2fe3ba838c5bd43dbe)
#         ;
#
#
#
#
#             var marker_8f12f15fe30a1234fa701e62

# %%
rental_cnu = [1016, 369, 1015, 366, 368, 1014, 367]

origin_data_path = os.path.join('preprocessed', '2022_season2_processed.csv')
origin_data = pd.read_csv(origin_data_path,
                          index_col=0,
                          parse_dates=['대여일시', '반납일시'],
                          infer_datetime_format=True)

origin_data.head()
# Out:
#     대여스테이션                대여일시  반납스테이션                반납일시  이동거리  rental_time
# 47       1 2022-07-23 10:12:20     985 2022-07-23 10:20:39   500          499
# 48     985 2022-07-23 10:23:19     885 2022-07-23 10:29:18   100          359
# 49     985 2022-07-23 10:23:24     885 2022-07-23 10:29:30   100          366
# 50     885 2022-07-23 10:33:08       1 2022-07-23 10:39:16   500          368
# 51     885 2022-07-23 10:33:17       1 2022-07-23 10:39:25   500          368

# %%
import numpy as np
def retain_from_index_array(target: pd.Series, index: np.ndarray) -> pd.Series:
    c = target.copy()
    for i, v in target.items():
        if v in index:      # if index array contains v
            c[i] = True     # retain this row.
        else:               # if not contains v
            c[i] = False    # remove this row.
    return c
filtered = origin_data.loc[retain_from_index_array(origin_data['반납스테이션'], rental_cnu)]
# def stamp2date(ts) -> str:
#     return ''.join([ts.year,ts.month,ts.day])
# df.apply

# %%
stat_dict = {}

def addToDict(d: dict, station: int):
    if not str(station) in d.keys():
        d[str(station)] = 1
    else:
        d[str(station)] += 1

filtered['대여스테이션'].apply(lambda x: addToDict(stat_dict, x))
stat_dict
# Out:
# {'769': 47,
#  '19': 64,
#  '1020': 218,
#  '85': 366,
#  '199': 309,
#  '192': 411,
#  '1021': 230,
#  '404': 224,
#  '412': 37,
#  '406': 167,
#  '1017': 133,
#  '1036': 19,
#  '381': 1,
#  '707': 12,
#  '92': 2,
#  '770': 68,
#  '194': 157,
#  '765': 334,
#  '763': 538,
#  '97': 37,
#  '395': 1,
#  '886': 82,
#  '1066': 28,
#  '1051': 91,
#  '768': 194,
#  '1025': 21,
#  '1064': 52,
#  '1052': 234,
#  '892': 100,
#  '215': 21,
#  '472': 3,
#  '485': 42,
#  '767': 77,
#  '4': 6,
#  '403': 77,
#  '191': 121,
#  '1015': 96,
#  '487': 70,
#  '1026': 8,
#  '351': 2,
#  '10': 1,
#  '193': 296,
#  '889': 31,
#  '103': 14,
#  '1016': 401,
#  '1058': 9,
#  '1024': 47,
#  '771': 44,
#  '1059': 1,
#  '393': 12,
#  '766': 130,
#  '377': 42,
#  '904': 8,
#  '887': 35,
#  '1038': 17,
#  '375': 37,
#  '448': 8,
#  '483': 25,
#  '195': 159,
#  '368': 82,
#  '735': 2,
#  '1084': 96,
#  '888': 69,
#  '1023': 326,
#  '764': 204,
#  '1065': 21,
#  '420': 8,
#  '1018': 164,
#  '196': 41,
#  '184': 7,
#  '21': 1,
#  '200': 78,
#  '238': 1,
#  '1085': 138,
#  '31': 1,
#  '760': 2,
#  '156': 8,
#  '376': 5,
#  '374': 16,
#  '91': 2,
#  '328': 14,
#  '428': 1,
#  '482': 82,
#  '407': 10,
#  '758': 1,
#  '488': 19,
#  '5': 1,
#  '330': 80,
#  '369': 55,
#  '398': 10,
#  '413': 18,
#  '1019': 46,
#  '442': 7,
#  '189': 1,
#  '327': 1,
#  '8': 6,
#  '455': 5,
#  '198': 104,
#  '155': 11,
#  '210': 6,
#  '1014': 62,
#  '445': 47,
#  '711': 22,
#  '773': 11,
#  '759': 7,
#  '366': 131,
#  '1': 166,
#  '172': 4,
#  '140': 10,
#  '1071': 16,
#  '1078': 6,
#  '185': 3,
#  '702': 8,
#  '337': 3,
#  '243': 4,
#  '367': 73,
#  '161': 18,
#  '1039': 13,
#  '772': 7,
#  '208': 24,
#  '1061': 16,
#  '331': 2,
#  '228': 4,
#  '197': 31,
#  '235': 1,
#  '169': 2,
#  '163': 2,
#  '333': 7,
#  '703': 25,
#  '446': 12,
#  '216': 11,
#  '394': 1,
#  '207': 3,
#  '234': 2,
#  '209': 6,
#  '90': 6,
#  '1029': 10,
#  '182': 13,
#  '891': 11,
#  '332': 5,
#  '94': 17,
#  '25': 5,
#  '1070': 12,
#  '447': 8,
#  '751': 2,
#  '910': 2,
#  '108': 1,
#  '232': 2,
#  '154': 2,
#  '205': 1,
#  '1110': 7,
#  '1027': 21,
#  '201': 38,
#  '96': 7,
#  '1056': 9,
#  '95': 6,
#  '165': 6,
#  '755': 2,
#  '774': 3,
#  '363': 1,
#  '20': 21,
#  '178': 4,
#  '449': 21,
#  '392': 1,
#  '203': 21,
#  '211': 7,
#  '17': 8,
#  '899': 6,
#  '1050': 15,
#  '241': 3,
#  '754': 5,
#  '706': 5,
#  '101': 8,
#  '188': 8,
#  '701': 12,
#  '417': 4,
#  '173': 1,
#  '777': 1,
#  '244': 1,
#  '22': 12,
#  '903': 18,
#  '401': 8,
#  '202': 5,
#  '452': 2,
#  '895': 1,
#  '418': 5,
#  '175': 1,
#  '462': 9,
#  '704': 10,
#  '98': 8,
#  '907': 6,
#  '134': 6,
#  '159': 3,
#  '790': 4,
#  '906': 4,
#  '432': 6,
#  '416': 7,
#  '900': 8,
#  '303': 1,
#  '164': 2,
#  '415': 7,
#  '12': 1,
#  '18': 9,
#  '1032': 1,
#  '454': 1,
#  '217': 2,
#  '183': 1,
#  '444': 8,
#  '224': 2,
#  '158': 5,
#  '347': 12,
#  '174': 3,
#  '162': 5,
#  '908': 4,
#  '385': 1,
#  '139': 8,
#  '435': 1,
#  '539': 1,
#  '456': 1,
#  '434': 2,
#  '705': 5,
#  '166': 1,
#  '131': 4,
#  '177': 1,
#  '93': 6,
#  '709': 9,
#  '526': 1,
#  '1037': 13,
#  '993': 3,
#  '741': 5,
#  '1127': 1,
#  '1087': 4,
#  '776': 1,
#  '421': 1,
#  '1034': 4,
#  '204': 4,
#  '503': 1,
#  '383': 3,
#  '132': 11,
#  '1111': 3,
#  '927': 1,
#  '710': 8,
#  '791': 1,
#  '918': 1,
#  '64': 1,
#  '789': 1,
#  '486': 5,
#  '14': 8,
#  '708': 10,
#  '388': 2,
#  '339': 2,
#  '750': 2,
#  '105': 4,
#  '361': 1,
#  '102': 6,
#  '426': 9,
#  '794': 10,
#  '240': 1,
#  '920': 1,
#  '911': 7,
#  '1033': 6,
#  '463': 1,
#  '752': 1,
#  '190': 1,
#  '99': 3,
#  '1140': 4,
#  '212': 9,
#  '382': 1,
#  '985': 3,
#  '13': 1,
#  '338': 7,
#  '1041': 2,
#  '431': 2,
#  '335': 2,
#  '206': 4,
#  '1145': 1,
#  '1135': 2,
#  '15': 1,
#  '1136': 4,
#  '405': 2,
#  '890': 3,
#  '176': 2,
#  '484': 10,
#  '225': 2,
#  '414': 1,
#  '679': 2,
#  '464': 4,
#  '400': 1,
#  '425': 4,
#  '833': 1,
#  '433': 3,
#  '873': 1,
#  '787': 1,
#  '716': 3,
#  '278': 1,
#  '3': 2,
#  '451': 2,
#  '379': 2,
#  '738': 6,
#  '260': 1,
#  '467': 1,
#  '399': 1,
#  '714': 2,
#  '100': 3,
#  '468': 1,
#  '817': 3,
#  '991': 1,
#  '229': 1,
#  '1030': 3,
#  '453': 4,
#  '712': 1,
#  '119': 4,
#  '1031': 2,
#  '11': 1,
#  '1075': 1,
#  '153': 1,
#  '989': 1,
#  '780': 1,
#  '983': 2,
#  '118': 17,
#  '326': 2,
#  '213': 3,
#  '761': 1,
#  '152': 2,
#  '1165': 3,
#  '230': 1,
#  '990': 2,
#  '902': 2,
#  '160': 4,
#  '901': 1,
#  '378': 1,
#  '796': 1,
#  '733': 1,
#  '171': 5,
#  '220': 1,
#  '1069': 2,
#  '242': 2,
#  '788': 2,
#  '386': 1,
#  '1173': 4,
#  '214': 1,
#  '466': 1,
#  '280': 1,
#  '409': 1,
#  '221': 2,
#  '718': 1,
#  '880': 1,
#  '419': 2,
#  '1172': 1,
#  '439': 1,
#  '127': 1,
#  '692': 1,
#  '713': 1,
#  '905': 1,
#  '1125': 1,
#  '179': 1,
#  '117': 3,
#  '128': 1,
#  '222': 1,
#  '124': 1}

# %%
x = stat_dict.keys()
y = stat_dict.values()

rentaldf = pd.DataFrame(data={'대여스테이션': x, '빈도': y})
rentaldf
# Out:
#     대여스테이션   빈도
# 0      769   47
# 1       19   64
# 2     1020  218
# 3       85  366
# 4      199  309
# ..     ...  ...
# 355    179    1
# 356    117    3
# 357    128    1
# 358    222    1
# 359    124    1
#
# [360 rows x 2 columns]

# %%
rentaldf = rentaldf.sort_values(by='빈도', ascending=False)
top10rental = rentaldf.head(30)
top10rental
# Out:
#     대여스테이션   빈도
# 18     763  538
# 5      192  411
# 44    1016  401
# 3       85  366
# 17     765  334
# 63    1023  326
# 4      199  309
# 41     193  296
# 27    1052  234
# 6     1021  230
# 7      404  224
# 2     1020  218
# 64     764  204
# 24     768  194
# 9      406  167
# 106      1  166
# 67    1018  164
# 58     195  159
# 16     194  157
# 73    1085  138

# %%
rental_origin = pd.read_csv('preprocessed/season2_rental_office.csv')
# rental_origin_data = pd.read_excel('data/Daejeon_tashu_rental_office_list_.xlsx',
#                              sheet_name='대여소정보(시즌2)', 
#                              header=0,
#                              dtype={
#                                  '번호': int,
#                                  '구분': str,
#                                  '구': str,
#                                  '동': str,
#                                  '위도': float,
#                                  '경도': float,
#                                  '사용여부': str
#                              })
map2 = folium.Map(location=pos_cnu, tiles='OpenStreetMap', zoom_start=13)
for st in top10rental['대여스테이션']:
    # data = rental_origin_data.loc[rental_origin_data['번호']==int(st)]
    data = rental_origin.loc[rental_origin['번호'] == int(st)]
    # folium.Marker(location=[data['위도'], data['경도']],
    #               popup=folium.Popup(html=folium.IFrame(f"{data.iloc[0]['대여소명']}[{st}]: {stat_dict[st]}", height=60), 
    #                                  min_width=200, max_width=200),
    #               icon=folium.Icon()
    # ).add_to(map2)
    folium.Circle(location=[data['위도'], data['경도']],
                  radius=20,
                  color='#eb920c',
                  fill_color='#000000',
                  popup=folium.Popup(html=folium.IFrame(f"{data.iloc[0]['대여소명']}[{st}]: {stat_dict[st]}", height=60), 
                                     min_width=200, max_width=200)
                  ).add_to(map2)
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83ce1ed175fd002a1b04d830c6838a0f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83ce1ed175fd002a1b04d830c6838a0f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83ce1ed175fd002a1b04d830c6838a0f = L.map(
#                 &quot;map_83ce1ed175fd002a1b04d830c6838a0f&quot;,
#                 {
#                     center: [36.3687979, 127.3468559],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34795594d7526e9af279e44b75245fdd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_83ce1ed175fd002a1b04d830c6838a0f);
#
#
#             var circle_0a32abbd9401d68a298c7443d4755352 = L.circle(
#                 [36.363151, 127.352945],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#eb920c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_83ce1ed175fd002a1b04d830c6838a0f);
#
#
#         var popup_98e6f0c3d45e61e63dd8dfc8811ac17a = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#
#                 var i_frame_a06333fe7e18df3df58665ff26f12886 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICDslrTsnYDrj5kg7ZWc67mb7JWE7YyM7Yq4IDEyNuuPmVs3NjNdOiA1Mzg=&quot; width=&quot;100%&quot; style=&quot;border:none !important;&quot; height=&quot;60&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_98e6f0c3d45e61e63dd8dfc8811ac17a.setContent(i_frame_a06333fe7e18df3df58665ff26f12886);
#
#
#
#         circle_0a32abbd9401d68a298c7443d4755352.bindPopup(popup_98e6f0c3d45e61e63dd8dfc8811ac17a)
#         ;
#
#
#
#
#             var circle_cf1fbdd4f57848cd6b2caac165e5e66b = L.circle(
#                 [36.361324, 127.34789],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#eb920c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_83ce1ed175fd002a1b04d830c6838a0f);
#
#
#         var popup_ec794506b307d14ceeed3ae038f3e8f3 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#
#                 var i_frame_0e3904ffd4c24e495ade64568e64ed13 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICDqtoHrj5kg64uk7IaU7JWE7YyM7Yq4IOyeheq1rFsxOTJdOiA0MTE=&quot; width=&quot;100%&quot; style=&quot;border:none !important;&quot; height=&quot;60&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_ec794506b307d14ceeed3ae038f3e8f3.setContent(i_frame_0e3904ffd4c24e495ade64568e64ed13);
#
#
#
#         circle_cf1fbdd4f57848cd6b2caac165e5e66b.bindPopup(popup_ec794506b307d14ceeed3ae038f3e8f3)
#         ;
#
#
#
#
#             var circle_2878576eae51f0c9e5a81ec70f5e044b = L.circle(
#                 [36.366431, 127.345595],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#eb920c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_83ce1ed175fd002a1b04d830c6838a0f);
#
#
#         var popup_30fae2f5887022b152d6a77af75afac5 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#
#                 var i_frame_6ee40c933d029a38f79dc24cccf34ec0 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICDstqnrjIAg7ZWZ7IOd7ZqM6rSAWzEwMTZdOiA0MDE=&quot; width=&quot;100%&quot; style=&quot;border:none !important;&quot; height=&quot;60&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_30fae2f5887022b152d6a77af75afac5.setContent(i_frame_6ee40c933d029a38f79dc24cccf34ec0);
#
#
#
#         circle_2878576eae51f0c9e5a81ec70f5e044b.bindPopup(popup_30fae2f5887022b152d6a77af75afac5)
#         ;

# %%
# 대여(-)/음봉, 반납(+)/양봉
target_rental = stat_dict.keys()

def addToDict(d, date:str, val: int):
    if not date in d.keys():
        d[date] = val
    else:
        d[date] += val

Average = {}
for i in target_rental:
    ii = int(i)

    # 하루에 반납-대여 차이가 얼마나 나는지 기록하는 딕셔너리
    # key = YYYYmmdd | value = (반납-대여)
    moment_temp = {}

    rent_df= origin_data.loc[origin_data['대여스테이션'] == ii]
    return_df = origin_data.loc[origin_data['반납스테이션'] == ii]
    rent_temp = rent_df['대여일시']
    return_temp = return_df['반납일시']

    # 대여했으므로 스테이션 잔여 오프셋에서 -1
    for d in rent_temp:
        stringified = f'{d.year}{d.month:02d}{d.day:02d}'
        addToDict(moment_temp, stringified, -1)
    # 반납했으므로 +1
    for d in return_temp:
        stringified = f'{d.year}{d.month:02d}{d.day:02d}'
        addToDict(moment_temp, stringified, 1)

    # 평균계산
    Average[i] = sum(moment_temp.values())/len(moment_temp)

for r in top10rental['대여스테이션']:
    print(r, Average[r])
# Out:
# 763 0.45806451612903226
# 192 -0.5612903225806452
# 1016 -0.6959459459459459
# 85 -0.310126582278481
# 765 0.18471337579617833
# 1023 0.6274509803921569
# 199 0.0641025641025641
# 193 -0.06535947712418301
# 1052 0.040268456375838924
# 1021 -0.21153846153846154
# 404 0.5125
# 1020 -1.3509933774834437
# 764 0.15384615384615385
# 768 -0.5379746835443038
# 406 -0.6163522012578616
# 1 41.320754716981135
# 1018 0.8639455782312925
# 195 0.48366013071895425
# 194 0.2532467532467532
# 1085 -0.44285714285714284

# %%
from math import atan
map3 = folium.Map(location=pos_cnu, tiles='OpenStreetMap', zoom_start=13)
fg_marker = folium.FeatureGroup(name='Location_marker').add_to(map3)
fg_chart = folium.FeatureGroup(name='Usage').add_to(map3)
line_offset = 0.0007    # 중심점으로부터 차트를 얼마만큼 떨어진 거리에서 보여줄지 결정

def scaler(x):  # 차트 스케일 함수
    return 0.002*atan(x)

for st in top10rental['대여스테이션']:
    # data = rental_origin_data.loc[rental_origin_data['번호']==int(st)]
    data = rental_origin.loc[rental_origin['번호'] == int(st)]

    # 위치를 보기 쉽게 큰 마커로 표현해줌
    folium.Marker(location=[data['위도'], data['경도']],
                  popup=folium.Popup(html=folium.IFrame(f"{data.iloc[0]['대여소명']}[{st}]: {stat_dict[st]}", height=60), 
                                     min_width=200, max_width=200),
                  icon=folium.Icon()
    ).add_to(fg_marker)

    # 중심점으로부터 차트를 그릴 곳까지 잇는 선
    loc = [(float(data['위도']), float(data['경도'])), (float(data['위도']), float(data['경도'])+line_offset)]
    folium.PolyLine(locations=loc, color='orange', weight=5).add_to(fg_chart)
    
    # 중심점 원
    folium.Circle(location=[data['위도'], data['경도']],
                  radius=20,
                  color='#eb920c',
                  fill_color='#000000',
                  popup=folium.Popup(html=folium.IFrame(f"{data.iloc[0]['대여소명']}[{st}]: {stat_dict[st]}", height=60), 
                                     min_width=200, max_width=200)
    ).add_to(fg_chart)

    # 차트
    chart_offset = Average[st]    
    folium.PolyLine(locations=(loc[1], (loc[1][0]+scaler(chart_offset), loc[1][1])),
                    color='red' if chart_offset < 0 else 'blue',
                    weight=5).add_to(fg_chart)

folium.LayerControl(collapsed=False).add_to(map3)
map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01d1b2521c603e2048f20dd617bea352 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01d1b2521c603e2048f20dd617bea352&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01d1b2521c603e2048f20dd617bea352 = L.map(
#                 &quot;map_01d1b2521c603e2048f20dd617bea352&quot;,
#                 {
#                     center: [36.3687979, 127.3468559],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_021030e8a4ae24f9199ceec4ceccc085 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_01d1b2521c603e2048f20dd617bea352);
#
#
#             var feature_group_0094a62bd5de70a3e12c813c64c1236b = L.featureGroup(
#                 {}
#             ).addTo(map_01d1b2521c603e2048f20dd617bea352);
#
#
#             var marker_da30a909ea0b9e80e3243c966db480b0 = L.marker(
#                 [36.363151, 127.352945],
#                 {}
#             ).addTo(feature_group_0094a62bd5de70a3e12c813c64c1236b);
#
#
#             var icon_11bfce5179b59903f56e4020b86e0cfd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_da30a909ea0b9e80e3243c966db480b0.setIcon(icon_11bfce5179b59903f56e4020b86e0cfd);
#
#
#         var popup_bfb51ad0f880eb9067f4f2225f06442b = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#
#                 var i_frame_7a711e475c654d2e5907644314b6e36e = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICDslrTsnYDrj5kg7ZWc67mb7JWE7YyM7Yq4IDEyNuuPmVs3NjNdOiA1Mzg=&quot; width=&quot;100%&quot; style=&quot;border:none !important;&quot; height=&quot;60&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_bfb51ad0f880eb9067f4f2225f06442b.setContent(i_frame_7a711e475c654d2e5907644314b6e36e);
#
#
#
#         marker_da30a909ea0b9e80e3243c966db480b0.bindPopup(popup_bfb51ad0f880eb9067f4f2225f06442b)
#         ;
#
#
#
#
#             var marker_18b439774bc922d2b5ad261c59025544 = L.marker(
#                 [36.361324, 127.34789],
#                 {}
#             ).addTo(feature_group_0094a62bd5de70a3e12c813c64c1236b);
#
#
#             var icon_bf94ac62a8e06c5934fd9500f5c164ed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_18b439774bc922d2b5ad261c59025544.setIcon(icon_bf94ac62a8e06c5934fd9500f5c164ed);
#
#
#         var popup_b705af3490885906a839872249b5144a = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#
#                 var i_frame_c34426a85e667500ff2267686d82f763 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICDqtoHrj5kg64uk7IaU7JWE7YyM7Yq4IOyeheq1rFsxOTJdOiA0MTE=&quot; width=&quot;100%&quot; style=&quot;border:none !important;&quot; height=&quot;60&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_b705af3490885906a839872249b5144a.setContent(i_frame_c34426a85e667500ff2267686d82f763);
#
#
#
#         marker_18b439774bc922d2b5ad261c59025544.bindPopup(popup_b705af3490885906a839872249b5144a)
#         ;
#
#
#
#
#             var marker_42a8463299549ddbadf8954afaded416 = L.marker(
#                 [36.366431, 127.345595],
#                 {}
#             ).addTo(feature_group_0094a62bd5de70a3e12c813c64c1236b);
#
#
#             var icon_4e48aacc68aff4d15330b72346fa45b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_42a8463299549ddbadf8954afaded416.setIcon(icon_4e48aacc68aff4d15330b72346fa45b7);
#
#
#         var popup_2fb8cdc30e5ff98b52461070505e98ab = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#
#                 var i_frame_ca56f7a2344d61f0f3a1a51c3b8e9af9 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICDstqnrjIAg7ZWZ7IOd7ZqM6rSAWzEwMTZdOiA0MDE=&quot; width=&quot;100%&quot; style=&quot;border:none !important;&quot; height=&quot;60&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_2fb8cdc30e5ff98b52461070505e98ab.setContent(i_frame_ca56f7a2344d61f0f3a1a51c3b
